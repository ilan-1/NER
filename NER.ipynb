# %% [markdown]
# <h2 align=center> Named Entity Recognition (NER) using LSTMs with Keras</h2>

# %% [markdown]
# ### Task 1: Project Overview and Import Modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
np.random.seed(0)
plt.style.use("ggplot")

import tensorflow as tf
print('Tensorflow version:', tf.__version__)
print('GPU detected:', tf.config.list_physical_devices('GPU'))
# Out:
# Tensorflow version: 2.5.0
# GPU detected: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Task 2: Load and Explore the NER Dataset

# %% [markdown]
# EssentialEssential*Essential info about tagged entities*:
# - geo = Geographical Entity
# - org = Organization
# - per = Person
# - gpe = Geopolitical Entity
# - tim = Time indicator
# - art = Artifact
# - eve = Event
# - nat = Natural Phenomenon

# %%
data = pd.read_csv("ner_dataset.csv", encoding="latin1")
data = data.fillna(method="ffill")
data.head(20)
# Out:
#      Sentence #           Word  POS    Tag
# 0   Sentence: 1      Thousands  NNS      O
# 1   Sentence: 1             of   IN      O
# 2   Sentence: 1  demonstrators  NNS      O
# 3   Sentence: 1           have  VBP      O
# 4   Sentence: 1        marched  VBN      O
# 5   Sentence: 1        through   IN      O
# 6   Sentence: 1         London  NNP  B-geo
# 7   Sentence: 1             to   TO      O
# 8   Sentence: 1        protest   VB      O
# 9   Sentence: 1            the   DT      O
# 10  Sentence: 1            war   NN      O
# 11  Sentence: 1             in   IN      O
# 12  Sentence: 1           Iraq  NNP  B-geo
# 13  Sentence: 1            and   CC      O
# 14  Sentence: 1         demand   VB      O
# 15  Sentence: 1            the   DT      O
# 16  Sentence: 1     withdrawal   NN      O
# 17  Sentence: 1             of   IN      O
# 18  Sentence: 1        British   JJ  B-gpe
# 19  Sentence: 1         troops  NNS      O

# %%
print("Unique words in corpus:", data['Word'].nunique())
print("Unique tags in corpus:", data['Tag'].nunique())
# Out:
# Unique words in corpus: 35178
# Unique tags in corpus: 17

# %%
words = list(set(data["Word"].values))
words.append("ENDPAD")
num_words = len(words)

# %%
tags = list(set(data["Tag"].values))
num_tags = len(tags)

# %% [markdown]
# ### Task 3: Retrieve Sentences and Corresponsing Tags

# %%
class SentenceGetter(object):
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        self.empty = False
        agg_func = lambda s: [(w, p, t) for w, p, t in zip(s["Word"].values.tolist(),
                                                           s["POS"].values.tolist(),
                                                           s["Tag"].values.tolist())]
        self.grouped = self.data.groupby("Sentence #").apply(agg_func)
        self.sentences = [s for s in self.grouped]
    
    def get_next(self):
        try:
            s = self.grouped["Sentence: {}".format(self.n_sent)]
            self.n_sent += 1
            return s
        except:
            return None

# %%
getter = SentenceGetter(data)
sentences = getter.sentences

# %%
sentences[0]
# Out:
# [('Thousands', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('demonstrators', 'NNS', 'O'),
#  ('have', 'VBP', 'O'),
#  ('marched', 'VBN', 'O'),
#  ('through', 'IN', 'O'),
#  ('London', 'NNP', 'B-geo'),
#  ('to', 'TO', 'O'),
#  ('protest', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('war', 'NN', 'O'),
#  ('in', 'IN', 'O'),
#  ('Iraq', 'NNP', 'B-geo'),
#  ('and', 'CC', 'O'),
#  ('demand', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('withdrawal', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('British', 'JJ', 'B-gpe'),
#  ('troops', 'NNS', 'O'),
#  ('from', 'IN', 'O'),
#  ('that', 'DT', 'O'),
#  ('country', 'NN', 'O'),
#  ('.', '.', 'O')]

# %% [markdown]
# ### Task 4: Define Mappings between Sentences and Tags

# %%
word2idx = {w: i + 1 for i, w in enumerate(words)}
tag2idx = {t: i for i, t in enumerate(tags)}

# %%
word2idx
# Out:
# {'suitors': 1,
#  'month-old': 2,
#  'Gambari': 3,
#  'Zevallos': 4,
#  'formalized': 5,
#  'Intelogic': 6,
#  'draught': 7,
#  'Shaleyste': 8,
#  'obey': 9,
#  'channeled': 10,
#  '39': 11,
#  'vital': 12,
#  'freestyle': 13,
#  'Several': 14,
#  'Zalmay': 15,
#  'Giri': 16,
#  'prayers': 17,
#  'continues': 18,
#  'Iowa': 19,
#  'Lebanese-Syrian': 20,
#  'Significant': 21,
#  'retracted': 22,
#  'lower-priced': 23,
#  'Nyein': 24,
#  'Plutonium': 25,
#  'caressed': 26,
#  'al-Shara': 27,
#  'antagonist': 28,
#  'prints': 29,
#  'Qazi': 30,
#  'Williams': 31,
#  'previous': 32,
#  '346': 33,
#  'Hegang': 34,
#  'Tsholotsho': 35,
#  '10-point': 36,
#  'testimony': 37,
#  'clunkers': 38,
#  '35-year-old': 39,
#  'flaring': 40,
#  'Sharipov': 41,
#  'rent': 42,
#  'ShopperTrak': 43,
#  'Visegrad': 44,
#  'Rehman': 45,
#  'Zamboanga': 46,
#  'Adawe': 47,
#  'lawless': 48,
#  'high': 49,
#  'Toledo': 50,
#  'Westminster': 51,
#  'guileful': 52,
#  'ago': 53,
#  'association': 54,
#  'mid': 55,
#  'simulated': 56,
#  'endeavoured': 57,
#  'Affairs': 58,
#  'kicks': 59,
#  'compelled': 60,
#  'forbade': 61,
#  'co-founder': 62,
#  'Gration': 63,
#  'Fitzpatrick': 64,
#  'dictatorial': 65,
#  'Mubarak': 66,
#  'Dark': 67,
#  'deceitful': 68,
#  'number-five': 69,
#  '6.7': 70,
#  'fiercely': 71,
#  'ties': 72,
#  'advisers': 73,
#  '1.125': 74,
#  'Hkamti': 75,
#  'Suspected': 76,
#  'kissing': 77,
#  'ringleader': 78,
#  'weather': 79,
#  'African-Union': 80,
#  'mm': 81,
#  'Moreover': 82,
#  'Unocal-Chevron': 83,
#  'Bjorn': 84,
#  'Anh': 85,
#  'blockade': 86,
#  'buyer': 87,
#  'recall': 88,
#  'Murtha': 89,
#  'prayer': 90,
#  'rejoined': 91,
#  'disintegrated': 92,
#  'sabotage': 93,
#  'vacation': 94,
#  'Canada-US': 95,
#  'catch': 96,
#  'Parvez': 97,
#  'convenient': 98,
#  'GAO': 99,
#  'Omanis': 100,
#  'relevant': 101,
#  'Napa': 102,
#  'sunspots': 103,
#  'demolition': 104,
#  'Wheeler': 105,
#  'Observing': 106,
#  'overlooked': 107,
#  'dot': 108,
#  'Gijs': 109,
#  'alliances': 110,
#  'Jing': 111,
#  'Wengen': 112,
#  'produces': 113,
#  'standards': 114,
#  'Salik': 115,
#  '820': 116,
#  'target': 117,
#  'Colleagues': 118,
#  'Duluth': 119,
#  'million': 120,
#  'dilapidated': 121,
#  'channels': 122,
#  'grim': 123,
#  'Bashar': 124,
#  '221': 125,
#  'Reservist': 126,
#  'mundane': 127,
#  'Kapilvastu': 128,
#  '782': 129,
#  'Harriet': 130,
#  'Atal': 131,
#  '16-team': 132,
#  'accuses': 133,
#  'Vahidi': 134,
#  'VERY': 135,
#  'Adrien': 136,
#  'mortgage': 137,
#  'Ferrero': 138,
#  'Otri': 139,
#  'Medics': 140,
#  'laborers': 141,
#  'notched': 142,
#  'alienate': 143,
#  'sets': 144,
#  'Hugh': 145,
#  'cover': 146,
#  'boisterous': 147,
#  'Saqiz': 148,
#  'Khata': 149,
#  'cremation': 150,
#  'strikeouts': 151,
#  'constructive': 152,
#  'calamity': 153,
#  'Kuo': 154,
#  'al-Rubaei': 155,
#  'traditional': 156,
#  'Robben': 157,
#  '90-81': 158,
#  'Letimalo': 159,
#  'Khanna': 160,
#  'forgiveness': 161,
#  'vegetation': 162,
#  'structurally': 163,
#  'oral': 164,
#  'Caicos': 165,
#  '0.3': 166,
#  'hip-hop': 167,
#  'Nations': 168,
#  'blackout': 169,
#  '3,268': 170,
#  'rage': 171,
#  'quoting': 172,
#  'Ward': 173,
#  'pre-storm': 174,
#  'Matinpour': 175,
#  'executives': 176,
#  'mortification': 177,
#  'four-person': 178,
#  'Physician': 179,
#  'Goulash': 180,
#  'fewer': 181,
#  'surged': 182,
#  'Tirin': 183,
#  'Valery': 184,
#  'Poleo': 185,
#  'practiced': 186,
#  'overly': 187,
#  'earthquake-triggered': 188,
#  'Differences': 189,
#  'India': 190,
#  'DIA': 191,
#  'Lt.-Gen.': 192,
#  'Shamil': 193,
#  '°C': 194,
#  'timely': 195,
#  'penal': 196,
#  'mutton': 197,
#  'dense': 198,
#  'outsold': 199,
#  'cold-weather': 200,
#  'deadline': 201,
#  'Telephone': 202,
#  'Onassis': 203,
#  'speeding': 204,
#  'Here': 205,
#  'pelted': 206,
#  'nationally': 207,
#  'Telecom': 208,
#  'swiftly': 209,
#  'Colonized': 210,
#  'entertained': 211,
#  'wild-boar': 212,
#  'undercut': 213,
#  'Krakow': 214,
#  'homeowners': 215,
#  'specified': 216,
#  'Environment': 217,
#  'stomachs': 218,
#  'prices': 219,
#  'Tupolev': 220,
#  'co-conspirator': 221,
#  'Girl': 222,
#  'firms': 223,
#  'ATP': 224,
#  'shorter-range': 225,
#  'recluse': 226,
#  'sultanate': 227,
#  'heyday': 228,
#  'couples': 229,
#  'cursed': 230,
#  'ligament': 231,
#  'frightening': 232,
#  'Treatment': 233,
#  'donkey': 234,
#  'Ntawukulilyayo': 235,
#  'skyline': 236,
#  'Stirling': 237,
#  'degenerative': 238,
#  'Yediot': 239,
#  'overloaded': 240,
#  'boom': 241,
#  'irremediable': 242,
#  'Beckett': 243,
#  'islands': 244,
#  'Islets': 245,
#  'Levinson': 246,
#  'A&M': 247,
#  'whaling': 248,
#  'Osman': 249,
#  '\x96': 250,
#  'Iraqi': 251,
#  'taxis': 252,
#  'Iacovou': 253,
#  'quake-zone': 254,
#  'rape': 255,
#  'Initiatives': 256,
#  'Salomi': 257,
#  'Perhaps': 258,
#  'redeployment': 259,
#  'Sentences': 260,
#  '38': 261,
#  'Caribbean': 262,
#  'foundations': 263,
#  'Notice': 264,
#  'caravan': 265,
#  'Hurriyah': 266,
#  'Pavarotti': 267,
#  'lodged': 268,
#  'Shaffi': 269,
#  'improperly': 270,
#  'Keith': 271,
#  '1910': 272,
#  'resonated': 273,
#  'detaining': 274,
#  'anything': 275,
#  'salary': 276,
#  'intifada': 277,
#  'Gold': 278,
#  'two-week-old': 279,
#  'AP': 280,
#  'scandal': 281,
#  'inalienable': 282,
#  'Aweil': 283,
#  'shipping': 284,
#  'Nouri': 285,
#  'starlets': 286,
#  'U.S.-led': 287,
#  'vigilantes': 288,
#  'Anne-Marie': 289,
#  'Kiriyenko': 290,
#  'fundamentalist': 291,
#  'al-Mutairi': 292,
#  'bigger': 293,
#  'only': 294,
#  'shoving': 295,
#  'spiral': 296,
#  'Al-Qawasmi': 297,
#  'perceive': 298,
#  'staunchly': 299,
#  '03-Feb': 300,
#  'Rabiyaa': 301,
#  'copper': 302,
#  'rehabilitate': 303,
#  'inhabited': 304,
#  'non-Muslims': 305,
#  'meddles': 306,
#  'lifeline': 307,
#  'Waaq': 308,
#  'ills': 309,
#  '7.4': 310,
#  'Ruini': 311,
#  'Was': 312,
#  'Thun': 313,
#  'veiled': 314,
#  'balances': 315,
#  'ringing': 316,
#  'vaguely': 317,
#  'Marines': 318,
#  'tarnishing': 319,
#  'Shafi': 320,
#  'Barman': 321,
#  'Ul-Islam': 322,
#  'deminers': 323,
#  'Owen': 324,
#  'dread': 325,
#  'technocrats': 326,
#  'heroism': 327,
#  're-join': 328,
#  'meaning': 329,
#  'Street': 330,
#  'anyplace': 331,
#  'relates': 332,
#  'concordat': 333,
#  'famed': 334,
#  'Jr.': 335,
#  'Gun': 336,
#  'al-Haidari': 337,
#  'Xiamen': 338,
#  'shortened': 339,
#  'faulted': 340,
#  'Non-Violent': 341,
#  'Guardians': 342,
#  'Peugeot-Citroen': 343,
#  'Maldives': 344,
#  'begged': 345,
#  'tin': 346,
#  'Republican': 347,
#  '135': 348,
#  'enhances': 349,
#  'cured': 350,
#  'Mulally': 351,
#  'Soviet-built': 352,
#  'special': 353,
#  'orchestrate': 354,
#  'Maghreb': 355,
#  'blend': 356,
#  'Mwaluka': 357,
#  'formalize': 358,
#  'rocket-propelled': 359,
#  '17.9': 360,
#  'fertile': 361,
#  '8956-kilometer': 362,
#  'Vucelic': 363,
#  'Phillip': 364,
#  'Roseneft': 365,
#  'heighten': 366,
#  'appeasing': 367,
#  'sits': 368,
#  'disrepute': 369,
#  'plaque': 370,
#  '1,900': 371,
#  'Ramon': 372,
#  '6.3': 373,
#  'Kwan': 374,
#  'Savannah': 375,
#  'AIDS-related': 376,
#  'sprees': 377,
#  'reciprocate': 378,
#  'faults': 379,
#  'jail': 380,
#  'EMU': 381,
#  'near-term': 382,
#  'CSW': 383,
#  '1968': 384,
#  'anti-proliferation': 385,
#  'Cube': 386,
#  'procurement': 387,
#  'patrons': 388,
#  'Wave': 389,
#  'click': 390,
#  'Dagoberto': 391,
#  'wells': 392,
#  'terrorism-related': 393,
#  'il': 394,
#  'Eskom': 395,
#  '1809': 396,
#  '76.4': 397,
#  'remarkably': 398,
#  'honest': 399,
#  'Fogh': 400,
#  'Helium': 401,
#  'outpost': 402,
#  '218': 403,
#  'unified': 404,
#  'Flores': 405,
#  'Left': 406,
#  'future': 407,
#  'female': 408,
#  'dining': 409,
#  'al-Libbi': 410,
#  'roulette': 411,
#  'Implementation': 412,
#  'jog': 413,
#  'secessionists': 414,
#  'Clean': 415,
#  'Zenawi': 416,
#  'torn': 417,
#  'Mauro': 418,
#  'wrested': 419,
#  'backlash': 420,
#  '0.19': 421,
#  'newly-elected': 422,
#  '74th': 423,
#  'Luzhkov': 424,
#  'buried': 425,
#  'plumes': 426,
#  'Resource': 427,
#  'ownership': 428,
#  'adhere': 429,
#  'Zamani': 430,
#  'Sriharokota': 431,
#  'three-person': 432,
#  'inclusive': 433,
#  '1850': 434,
#  'Dilma': 435,
#  'array': 436,
#  'Syndrome': 437,
#  'heels': 438,
#  'Politician': 439,
#  'Sunnis': 440,
#  'groundhog': 441,
#  'buyers': 442,
#  'Socialists': 443,
#  'palm': 444,
#  'pro-government': 445,
#  'scurrying': 446,
#  'Bolton': 447,
#  'properties': 448,
#  'Preston': 449,
#  'thankful': 450,
#  'walking': 451,
#  'wintry': 452,
#  'quarrel': 453,
#  'Shaaban': 454,
#  'unsettled': 455,
#  'provinces': 456,
#  'Smells': 457,
#  'Mayen': 458,
#  'Insurance': 459,
#  'Roe': 460,
#  'Gaza-bound': 461,
#  'Polar': 462,
#  'Wabho': 463,
#  'storm-damaged': 464,
#  'Timbuktu': 465,
#  'sprinters': 466,
#  'Pich': 467,
#  'al-Mabhouh': 468,
#  'tsunami-affected': 469,
#  'Muslim-inhabited': 470,
#  'laughed': 471,
#  'Rigoberta': 472,
#  'assuring': 473,
#  'installation': 474,
#  'Yanjin': 475,
#  'Accordance': 476,
#  'Boldak': 477,
#  '3,50,000': 478,
#  'Teodoro': 479,
#  'Viktor': 480,
#  'uphold': 481,
#  '03-Mar': 482,
#  'Nguesso': 483,
#  'Cunha': 484,
#  'Rivalry': 485,
#  'hosted': 486,
#  'Manuel': 487,
#  'Nottingham': 488,
#  'all-cash': 489,
#  'differing': 490,
#  'configured': 491,
#  'gasses': 492,
#  'Prijedor': 493,
#  'Mix': 494,
#  'mediators': 495,
#  '11-nation': 496,
#  'By-election': 497,
#  'can': 498,
#  'Bagosora': 499,
#  '76.7': 500,
#  '3,000': 501,
#  'Assembly': 502,
#  'congratulation': 503,
#  'pedestal': 504,
#  'congregate': 505,
#  'Spyglass': 506,
#  'Prayer': 507,
#  'Munoz': 508,
#  'Marie-Paule': 509,
#  'fears': 510,
#  'Snake': 511,
#  'Hongdu': 512,
#  'classic': 513,
#  'year-end': 514,
#  'localized': 515,
#  'cancels': 516,
#  'lenghty': 517,
#  'eighties': 518,
#  'Czechoslovakia': 519,
#  'social-conservative': 520,
#  'Quami': 521,
#  'al-Aadham': 522,
#  'setbacks': 523,
#  'Patzi': 524,
#  'Revelers': 525,
#  'Taitung': 526,
#  'necks': 527,
#  'commemorates': 528,
#  'Zviad': 529,
#  'Folha': 530,
#  'battered': 531,
#  'Tuz': 532,
#  'coil': 533,
#  'weekends': 534,
#  'potentially': 535,
#  'clots': 536,
#  'Bolivarian': 537,
#  'Kulyab': 538,
#  'Mgalobishvili': 539,
#  'Graner': 540,
#  'Varanasi': 541,
#  'safety': 542,
#  'Delp': 543,
#  'Bancoro': 544,
#  'contingent': 545,
#  'VOA': 546,
#  'perception': 547,
#  'digital': 548,
#  'entitlements': 549,
#  'equestrian': 550,
#  'Ballack': 551,
#  'Hellenic': 552,
#  'Zionism': 553,
#  '10-member': 554,
#  'congresswoman': 555,
#  'strangle': 556,
#  'Tamil': 557,
#  'Zulima': 558,
#  'Latvia': 559,
#  'preceding': 560,
#  'Reinsurance': 561,
#  'Keck': 562,
#  'never': 563,
#  'Rolling': 564,
#  'onlookers': 565,
#  'Peipah': 566,
#  'Rivero': 567,
#  'Hague-based': 568,
#  'overruns': 569,
#  'Klara': 570,
#  '8.7': 571,
#  'boasts': 572,
#  'Pensacola': 573,
#  'acceptable': 574,
#  'Named': 575,
#  'over-rule': 576,
#  'Netanyahu': 577,
#  'luge': 578,
#  'intentionally': 579,
#  'pro-Musharraf': 580,
#  'Muluzi': 581,
#  'Policy': 582,
#  'paralysis': 583,
#  'teacher': 584,
#  '53-year-old': 585,
#  'youthful': 586,
#  'tell': 587,
#  'muscular': 588,
#  'madness': 589,
#  'Livio': 590,
#  'Argentines': 591,
#  'Vargas': 592,
#  'Swank': 593,
#  'gemstone': 594,
#  'newer': 595,
#  'toothfish': 596,
#  'Undeveloped': 597,
#  'Drapchi': 598,
#  'anarchist': 599,
#  'Ningxia': 600,
#  'refloating': 601,
#  'Beslan': 602,
#  '6,00,000': 603,
#  'de': 604,
#  'ignited': 605,
#  'Dhia': 606,
#  'dribbled': 607,
#  'Heirs': 608,
#  'anti-Taliban': 609,
#  'remainder': 610,
#  'Asir': 611,
#  'will': 612,
#  'forcers': 613,
#  'Zeal': 614,
#  'equals': 615,
#  'Finsbury': 616,
#  'Gucht': 617,
#  'headaches': 618,
#  'conflicts': 619,
#  'DVDs': 620,
#  'non-Arab': 621,
#  'undersecretary-general': 622,
#  'six-kilometers': 623,
#  'Chuck': 624,
#  'become': 625,
#  'Warning': 626,
#  'PetroChina': 627,
#  'Fund-Global': 628,
#  'al-Aqsa': 629,
#  'reparation': 630,
#  'Egypt-Gaza': 631,
#  'Tibetan': 632,
#  'seek': 633,
#  'Aden': 634,
#  'Chitchai': 635,
#  'Il.': 636,
#  'compared': 637,
#  'incorporation': 638,
#  'honoring': 639,
#  "Shi'ite-dominated": 640,
#  'temples': 641,
#  'Zapatero': 642,
#  'campaigned': 643,
#  'whispered': 644,
#  'magnitude': 645,
#  'spoke': 646,
#  'mudslide': 647,
#  'Jet': 648,
#  'line-of-control': 649,
#  '16-year': 650,
#  'unhindered': 651,
#  'hurricane-damaged': 652,
#  'Hopes': 653,
#  'detection': 654,
#  '1,64,000': 655,
#  'awaiting': 656,
#  'Khun': 657,
#  'Taking': 658,
#  'Base': 659,
#  'harbored': 660,
#  'shells': 661,
#  'Kappes': 662,
#  'Ansar': 663,
#  'Jinling': 664,
#  'down-turn': 665,
#  'snow-shortened': 666,
#  'calmed': 667,
#  'Gignor': 668,
#  '126.2': 669,
#  'Bloom': 670,
#  'colors': 671,
#  'plants': 672,
#  'contaminated': 673,
#  'Director-General': 674,
#  'Front': 675,
#  'Bouna': 676,
#  'plains': 677,
#  'Talal': 678,
#  'Intensified': 679,
#  'Odom': 680,
#  'l': 681,
#  'globally': 682,
#  'barcodes': 683,
#  'Khursheed': 684,
#  'Cite': 685,
#  '175-run': 686,
#  'manifestations': 687,
#  'AUNG': 688,
#  'correspondent': 689,
#  'plowed': 690,
#  'scratched': 691,
#  'outlawed': 692,
#  'hangar': 693,
#  'Maarib': 694,
#  'ruining': 695,
#  '23-member': 696,
#  'Nearby': 697,
#  'Toure': 698,
#  'Mirpur': 699,
#  '76': 700,
#  'Cesme': 701,
#  'launches': 702,
#  'truce': 703,
#  'permitted': 704,
#  'Mexicali': 705,
#  'seismological': 706,
#  'Rawood': 707,
#  'marchers': 708,
#  'Global': 709,
#  'Merchants': 710,
#  'Spanish': 711,
#  'juror': 712,
#  'Bilfinger': 713,
#  'Prior': 714,
#  'KTM': 715,
#  "'70s": 716,
#  'Arawak': 717,
#  'Rameez': 718,
#  'archival': 719,
#  'Shoppers': 720,
#  'Rafat': 721,
#  'rappers': 722,
#  'granite': 723,
#  'repealing': 724,
#  'Fakhar': 725,
#  'Palma': 726,
#  'weaponization': 727,
#  'Incoming': 728,
#  'whites': 729,
#  'employees': 730,
#  'handing': 731,
#  'al-Dulaymi': 732,
#  'papacy': 733,
#  'contra': 734,
#  'cafe': 735,
#  'Baby': 736,
#  'Bertrand': 737,
#  'whichever': 738,
#  'Soviet': 739,
#  'frustrated': 740,
#  'Yankee': 741,
#  'forms': 742,
#  'goverment': 743,
#  'Da': 744,
#  'benchmarks': 745,
#  'Naseem': 746,
#  '1917': 747,
#  'trunk': 748,
#  'tiebreaker': 749,
#  'proving': 750,
#  'one-percent': 751,
#  'harbors': 752,
#  'El-Obeid': 753,
#  'Azerbaijani': 754,
#  '43rd': 755,
#  'al-Sabah': 756,
#  'castoff': 757,
#  'enrich': 758,
#  'shantytowns': 759,
#  'Bin': 760,
#  '196': 761,
#  '58,000': 762,
#  'Belarusian': 763,
#  'double-standards': 764,
#  'Poncet': 765,
#  'deifies': 766,
#  '257': 767,
#  'Java': 768,
#  'topics': 769,
#  'Jaroslaw': 770,
#  'Shryock': 771,
#  'legal': 772,
#  'adulthood': 773,
#  'India-U.S.': 774,
#  'Baylesa': 775,
#  'Nadi': 776,
#  'economical': 777,
#  'abusing': 778,
#  'mill': 779,
#  'laureate': 780,
#  '136': 781,
#  'eat': 782,
#  'Funding': 783,
#  'Wei': 784,
#  'make-up': 785,
#  'President': 786,
#  'FAYYAD': 787,
#  'inscriptions': 788,
#  'downing': 789,
#  'Paulson': 790,
#  'obsessed': 791,
#  'land': 792,
#  'B': 793,
#  'scuffled': 794,
#  'Moutaz': 795,
#  'newly-appointed': 796,
#  'Katzenellenbogen': 797,
#  'Spaniard': 798,
#  'Ballenas': 799,
#  'mogul': 800,
#  'compensatiion': 801,
#  'four-kilometer': 802,
#  'Barranquilla': 803,
#  'May': 804,
#  'mideast': 805,
#  'Ruling': 806,
#  '145': 807,
#  'Kheyal': 808,
#  'jammed': 809,
#  'shatters': 810,
#  'Strasbourg': 811,
#  'Muttahida': 812,
#  'greed': 813,
#  'Allegiance': 814,
#  'atrophy': 815,
#  'something': 816,
#  'mountainous': 817,
#  'angioplasty': 818,
#  'visited': 819,
#  'Griffal': 820,
#  'Ravi': 821,
#  'appear': 822,
#  'petrochemical': 823,
#  'dealings': 824,
#  'radiological': 825,
#  'Intoning': 826,
#  'contradictory': 827,
#  'Horizons': 828,
#  'abruptly': 829,
#  'renewed': 830,
#  'Suspects': 831,
#  'harming': 832,
#  'masters': 833,
#  'Orellana': 834,
#  '4,200': 835,
#  'BOEDIONO': 836,
#  'bouncing': 837,
#  'abortion': 838,
#  'abrupt': 839,
#  'telephoning': 840,
#  'edict': 841,
#  'engagement': 842,
#  'Sfeir': 843,
#  'Wolfgang': 844,
#  'Leonid': 845,
#  'over': 846,
#  'deepen': 847,
#  'nutmeg': 848,
#  'Niaraki': 849,
#  'Jean-Paul': 850,
#  '\x85': 851,
#  '500': 852,
#  'arrangement': 853,
#  '59.9': 854,
#  'stranger': 855,
#  'listed': 856,
#  'C.': 857,
#  'checkup': 858,
#  'ivory': 859,
#  'Latvian': 860,
#  'arrow': 861,
#  'stint': 862,
#  'Portman': 863,
#  'Small-scale': 864,
#  'crossing': 865,
#  'centimeters': 866,
#  'Maurice': 867,
#  'killed': 868,
#  'Should': 869,
#  '315-member': 870,
#  'cemetery': 871,
#  'astonished': 872,
#  'night': 873,
#  'Rabiah': 874,
#  'frequencies': 875,
#  'Libby': 876,
#  'voted': 877,
#  'Lord': 878,
#  'strapped': 879,
#  'Areva': 880,
#  'Russian-built': 881,
#  'free-trade': 882,
#  'FIFA': 883,
#  'reprisals': 884,
#  'malachite': 885,
#  'aftershocks': 886,
#  'internal': 887,
#  'transport': 888,
#  'usually': 889,
#  'Aboriginal': 890,
#  '11.5': 891,
#  'Hardcourt': 892,
#  'tie': 893,
#  'Mukhtar': 894,
#  'astrology': 895,
#  'U.S.-made': 896,
#  'wants': 897,
#  'Hokkaido': 898,
#  'government-allied': 899,
#  'US-based': 900,
#  'lighten': 901,
#  '187': 902,
#  'atrocities': 903,
#  '311': 904,
#  'unidentified': 905,
#  'underscored': 906,
#  'jeopardized': 907,
#  'Australians': 908,
#  'jungle': 909,
#  'toilet': 910,
#  'afterward': 911,
#  'facilitated': 912,
#  'Berman': 913,
#  'Executive': 914,
#  'drunkard': 915,
#  '14-year': 916,
#  'POMEGRANATE': 917,
#  'Thein': 918,
#  'Ethnomusicologist': 919,
#  'bombings': 920,
#  'firearms': 921,
#  'Argentina': 922,
#  'embankment': 923,
#  'Seahawks': 924,
#  'inward': 925,
#  'moderates': 926,
#  'Warming': 927,
#  'combination': 928,
#  'spirit': 929,
#  'Cyprus': 930,
#  'meet': 931,
#  'plaguing': 932,
#  'reputation': 933,
#  'Rankings': 934,
#  'Avaricious': 935,
#  'bolstering': 936,
#  'harmonized': 937,
#  'Kosuke': 938,
#  'blue': 939,
#  'exit': 940,
#  'Closing': 941,
#  'Pakhtoonkhaw': 942,
#  'Hiriart': 943,
#  'nano-technology': 944,
#  'kilometers': 945,
#  'Globovision': 946,
#  'detected': 947,
#  'Kravchenko': 948,
#  'use': 949,
#  '58': 950,
#  'Salas': 951,
#  'remarried': 952,
#  'Franklin': 953,
#  'graveyards': 954,
#  'autonomy': 955,
#  'Massum': 956,
#  'Giving': 957,
#  'Lavrov': 958,
#  'intestine': 959,
#  '1755': 960,
#  'Representatives': 961,
#  'ally': 962,
#  'appointed': 963,
#  'Democratic-controlled': 964,
#  'streamlined': 965,
#  'melting': 966,
#  '58-year-old': 967,
#  'Diplomats': 968,
#  'dries': 969,
#  '74-year-old': 970,
#  'Anti-Chinese': 971,
#  'Hasegawa': 972,
#  '1.1': 973,
#  'one-to-one': 974,
#  'Eyharts': 975,
#  'authoritarian': 976,
#  'al-Sistani': 977,
#  'enroute': 978,
#  'Dallas': 979,
#  'Petrova': 980,
#  'siding': 981,
#  '1631': 982,
#  'cockroach': 983,
#  'Wit': 984,
#  'IWF': 985,
#  'Aalam': 986,
#  'windfall': 987,
#  'three-and-a-half': 988,
#  'decade-long': 989,
#  'fraction': 990,
#  'Citizen': 991,
#  'Game': 992,
#  'cascade': 993,
#  'rhythm-and-blues': 994,
#  'telecommunications': 995,
#  'Organization': 996,
#  'unhitches': 997,
#  'surrendered': 998,
#  'Noel': 999,
#  'inroads': 1000,
#  ...}

# %% [markdown]
# ### Task 5: Padding Input Sentences and Creating Train/Test Splits

# %%
plt.hist([len(s) for s in sentences], bins=50)
plt.show()

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

max_len = 50

X = [[word2idx[w[0]] for w in s] for s in sentences]
X = pad_sequences(maxlen=max_len, sequences=X, padding="post", value=num_words-1)

y = [[tag2idx[w[2]] for w in s] for s in sentences]
y = pad_sequences(maxlen=max_len, sequences=y, padding="post", value=tag2idx["O"])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# ### Task 6: Build and Compile a Bidirectional LSTM Model

# %%
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import LSTM, Embedding, Dense
from tensorflow.keras.layers import TimeDistributed, SpatialDropout1D, Bidirectional

# %%
input_word = Input(shape=(max_len,))
model = Embedding(input_dim=num_words, output_dim=50, input_length=max_len)(input_word)
model = SpatialDropout1D(0.1)(model)
model = Bidirectional(LSTM(units=100, return_sequences=True, recurrent_dropout=0.1))(model)
out = TimeDistributed(Dense(num_tags, activation="softmax"))(model)
model = Model(input_word, out)
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 50)]              0
# _________________________________________________________________
# embedding (Embedding)        (None, 50, 50)            1758950
# _________________________________________________________________
# spatial_dropout1d (SpatialDr (None, 50, 50)            0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 50, 200)           120800
# _________________________________________________________________
# time_distributed (TimeDistri (None, 50, 17)            3417
# =================================================================
# Total params: 1,883,167
# Trainable params: 1,883,167
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ### Task 7: Train the Model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
#from livelossplot.tf_keras import PlotLossesCallback

# %%
# %%time

chkpt = ModelCheckpoint("model_weights.h5", monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=True, mode='min')

early_stopping = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=1, verbose=0, mode='max', baseline=None, restore_best_weights=False)

callbacks = [ chkpt, early_stopping] #PlotLossesCallback(),

history = model.fit(
    x=x_train,
    y=y_train,
    validation_data=(x_test,y_test),
    batch_size=32, 
    epochs=3,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/3
# 1199/1199 [==============================] - 336s 271ms/step - loss: 0.1796 - accuracy: 0.9586 - val_loss: 0.0669 - val_accuracy: 0.9811
#
# Epoch 00001: val_loss improved from inf to 0.06692, saving model to model_weights.h5
# Epoch 2/3
# 1199/1199 [==============================] - 320s 267ms/step - loss: 0.0509 - accuracy: 0.9849 - val_loss: 0.0514 - val_accuracy: 0.9848
#
# Epoch 00002: val_loss improved from 0.06692 to 0.05136, saving model to model_weights.h5
# Epoch 3/3
# 1199/1199 [==============================] - 321s 268ms/step - loss: 0.0374 - accuracy: 0.9886 - val_loss: 0.0484 - val_accuracy: 0.9856
#
# Epoch 00003: val_loss improved from 0.05136 to 0.04838, saving model to model_weights.h5
# CPU times: user 41min 17s, sys: 3min 39s, total: 44min 56s
# Wall time: 16min 18s

# %% [markdown]
# ### Task 8: Evaluate Named Entity Recognition Model

# %%
model.evaluate(x_test, y_test)
# Out:
# 300/300 [==============================] - 8s 25ms/step - loss: 0.0484 - accuracy: 0.9856
# [0.04837547615170479, 0.9856213331222534]

# %%
i = np.random.randint(0, x_test.shape[0]) #659
p = model.predict(np.array([x_test[i]]))
p = np.argmax(p, axis=-1)
y_true = y_test[i]
print("{:15}{:5}\t {}\n".format("Word", "True", "Pred"))
print("-" *30)
for w, true, pred in zip(x_test[i], y_true, p[0]):
    print("{:15}{}\t{}".format(words[w-1], tags[true], tags[pred]))
# Out:
# Word           True 	 Pred
#
# ------------------------------
# Japanese       B-geo	B-gpe
# Foreign        B-per	O
# Minister       I-per	B-per
# Nobutaka       I-per	I-per
# Machimura      I-per	I-per
# said           O	O
# Wednesday      B-tim	B-tim
# the            O	O
# talks          O	O
# will           O	O
# include        O	O
# North          B-geo	B-geo
# Korea          I-geo	I-geo
# 's             O	O
# nuclear        O	O
# weapons        O	O
# program        O	O
# and            O	O
# the            O	O
# abductee       O	O
# issue          O	O
# .              O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
# two-and-half   O	O
